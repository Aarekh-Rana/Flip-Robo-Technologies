# %%
#!pip install selenium
from selenium import webdriver
from selenium.common import exceptions
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import os

# %%
#######setting driver for browsing##########

driver=webdriver.Chrome(executable_path='C://Users//aarek//Downloads//chromedriver_win32//chromedriver.exe')

# %%
#######Link of first page of mens trouser ##########

my_trousers=driver.get("https://www.flipkart.com/search?q=mens+trouser&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1")

# %%
#######Link of first page of mens jeans ##########

my_jeans=driver.get("https://www.flipkart.com/search?q=men+jeans&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1")

# %%
####### making directories/folder ###########

def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
make_directory("mens_pants//train//trousers" and "mens_pants//train//jeans")

# %%
make_directory("mens_pants//validation//trousers" and "mens_pants//validation//jeans")

# %%
########## Assigning the class of images of jeans/trouser ###########

images=driver.find_elements_by_xpath("//img[@class='_3togXc']")

# %%
user_requirement_url=100

# %%
#######Accessing multiple pages and scraping url of images by generating new link for every page##############

#################### Scraping url of Trouser Images ########################
urls_trouser=[]
page = 1
i = 0
while len(urls_trouser)<=(user_requirement_url):
    my_trousers=driver.get("https://www.flipkart.com/search?q=mens+trouser&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(page))
    page = page + 1
    images=driver.find_elements_by_xpath("//img[@class='_3togXc']")
    for image in images:
        if len(urls_trouser) == (user_requirement_url):
            i = 1
            break
        sources=image.get_attribute('src')
        urls_trouser.append(sources)
        print(len(urls_trouser))
        print(sources)    
    if i == 1:
        break
        
####################### Accessing multiple pages and scraping url of images by button click for new page #######################       
#urls_trouser=[]
#while len(urls_trouser)<=(user_requirement_url):  
    #for image in images:
        #if len(urls_trouser)==(user_requirement_url):
            #break;
       #sources=image.get_attribute('src')
        #urls.append(sources)
        #print(sources)
    #select = driver.find_element_by_xpath("//a[@class='_3fVaIS']")
    #select.click()
    #images=driver.find_elements_by_xpath("//img[@class='_3togXc']")#to restore the value of images from next page(current page)
        
###############################################################################################################################
# Out:
# 1
# https://rukminim1.flixcart.com/image/329/395/kbs9k7k0/trouser/a/e/g/30-preet-navy-balloon-pant-for-men-fashlook-original-imaft2e93hj68fga.jpeg?q=50
# 2
# https://rukminim1.flixcart.com/image/329/395/jz1l7rk0/trouser/j/u/s/30-astfwcrfo87872-allen-solly-original-imafj5keas9kbqu7.jpeg?q=50
# 3
# https://rukminim1.flixcart.com/image/329/395/jxf05u80/trouser/n/j/e/36-combo-trouser-baleno-blackand-green-aa-ad-av-original-imafhuqs5xrfhfzq.jpeg?q=50
# 4
# https://rukminim1.flixcart.com/image/329/395/jxqfonk0/trouser/k/w/z/28-bmw-cotton-trs-ben-martin-original-imafhh8yv8aybb2c.jpeg?q=50
# 5
# https://rukminim1.flixcart.com/image/329/395/k70spzk0/trouser/g/k/b/30-hltr003885-highlander-original-imafpchrxfmvzxrt.jpeg?q=50
# 6
# https://rukminim1.flixcart.com/image/329/395/k70spzk0/trouser/a/8/4/30-hltr003914-highlander-original-imafpchqwdkpgtyr.jpeg?q=50
# 7
# https://rukminim1.flixcart.com/image/329/395/k3t21zk0/trouser/e/h/d/36-kctr-5555-bk-fubar-original-imafmuzabfsh5yzp.jpeg?q=50
# 8
# ...

# %%
len(urls)
# Out:
# 100

# %%
#################### Downloading Scraped url of Trouser Images ########################

import shutil
import requests
for index, links in enumerate(urls_trouser):
    print ("downloading {0} of {1} images".format(index+1, len(urls_trouser)))
    response=requests.get(links)
    with open('mens_pants//train//trousers/img_{0}.jpeg'.format(index),"wb")as file:
        file.write(response.content)
# Out:
# downloading 1 of 100 images
# downloading 2 of 100 images
# downloading 3 of 100 images
# downloading 4 of 100 images
# downloading 5 of 100 images
# downloading 6 of 100 images
# downloading 7 of 100 images
# downloading 8 of 100 images
# downloading 9 of 100 images
# downloading 10 of 100 images
# downloading 11 of 100 images
# downloading 12 of 100 images
# downloading 13 of 100 images
# downloading 14 of 100 images
# downloading 15 of 100 images
# downloading 16 of 100 images
# downloading 17 of 100 images
# downloading 18 of 100 images
# downloading 19 of 100 images
# downloading 20 of 100 images
# downloading 21 of 100 images
# downloading 22 of 100 images
# downloading 23 of 100 images
# downloading 24 of 100 images
# downloading 25 of 100 images
# downloading 26 of 100 images
# downloading 27 of 100 images
# downloading 28 of 100 images
# downloading 29 of 100 images
# downloading 30 of 100 images
# downloading 31 of 100 images
# downloading 32 of 100 images
# ...

# %%
#################### Scraping url of jeans Images ########################

urls_jeans=[]
page = 1
i = 0
while len(urls_jeans)<=(user_requirement_url):
    my_trousers=driver.get("https://www.flipkart.com/search?q=men+jeans&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(page))
    page = page + 1
    images=driver.find_elements_by_xpath("//img[@class='_3togXc']")
    for image in images:
        if len(urls_jeans) == (user_requirement_url):
            i = 1
            break
        sources=image.get_attribute('src')
        urls_jeans.append(sources)
        print(len(urls_jeans))
        print(sources)    
    if i == 1:
        break
# Out:
# 1
# https://rukminim1.flixcart.com/image/329/395/k0wqwsw0/jean/z/g/9/32-maw19jn102-metronaut-original-imafkhfggwtz9bgy.jpeg?q=50
# 2
# https://rukminim1.flixcart.com/image/329/395/k0zlsi80/jean/y/t/u/32-udjno5141-u-s-polo-association-original-imafkz6fyhg34dsc.jpeg?q=50
# 3
# https://rukminim1.flixcart.com/image/329/395/jjylw280/jean/p/a/s/34-eps-black-03-urbano-fashion-original-imaf7f7wyy7sv6zk.jpeg?q=50
# 4
# https://rukminim1.flixcart.com/image/329/395/jean/n/u/3/bmw-darklevis-ben-martin-32-original-imaedpc4zcgjadsv.jpeg?q=50
# 5
# https://rukminim1.flixcart.com/image/329/395/jh6l2fk0/jean/4/a/z/30-lj183a-lzard-original-imaf5883mb8vchhb.jpeg?q=50
# 6
# https://rukminim1.flixcart.com/image/329/395/jsw3yq80/jean/j/c/c/32-mss19ajn020-metronaut-original-imafede5zhvgchsk.jpeg?q=50
# 7
# https://rukminim1.flixcart.com/image/329/395/jhavdzk0/jean/j/x/p/30-hpsjogger-lgrey-urbano-fashion-original-imaf5bzbhhvwu9by.jpeg?q=50
# 8
# ...

# %%
#################### Downloading Scraped url of jeans Images ########################

for index, links in enumerate(urls_jeans):
    print ("downloading {0} of {1} images".format(index+1, len(urls_jeans)))
    response=requests.get(links)
    with open('mens_pants//train//jeans/img_{0}.jpeg'.format(index),"wb")as file:
        file.write(response.content)
# Out:
# downloading 1 of 100 images
# downloading 2 of 100 images
# downloading 3 of 100 images
# downloading 4 of 100 images
# downloading 5 of 100 images
# downloading 6 of 100 images
# downloading 7 of 100 images
# downloading 8 of 100 images
# downloading 9 of 100 images
# downloading 10 of 100 images
# downloading 11 of 100 images
# downloading 12 of 100 images
# downloading 13 of 100 images
# downloading 14 of 100 images
# downloading 15 of 100 images
# downloading 16 of 100 images
# downloading 17 of 100 images
# downloading 18 of 100 images
# downloading 19 of 100 images
# downloading 20 of 100 images
# downloading 21 of 100 images
# downloading 22 of 100 images
# downloading 23 of 100 images
# downloading 24 of 100 images
# downloading 25 of 100 images
# downloading 26 of 100 images
# downloading 27 of 100 images
# downloading 28 of 100 images
# downloading 29 of 100 images
# downloading 30 of 100 images
# downloading 31 of 100 images
# downloading 32 of 100 images
# ...
